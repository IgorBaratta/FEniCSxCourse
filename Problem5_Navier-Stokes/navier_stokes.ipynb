# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorBaratta/FEniCSxCourse/blob/ICMC23/Problem5_Navier-Stokes/navier_stokes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Incompressible Navier-Stokes equations

# %% [markdown]
# ## Strong formulation
#
# The plan for this tutorial is to solve the prototypical **non-linear mixed** problem in fluid mechanics, namely, the **Navier-Stokes** equations in the incompressible regime.
# The main difficulties when discretizing the Navier-Stokes problem are related to
# the treatment of:
#
# * the pressure-velocity coupling (there is no equation for $p$;
# * the convective nonlinear term $\rho \,(\mathbf{u}\cdot \nabla)~\mathbf{u}$
# * boundary layers and turbulent flows
#
# Let us recall the problem in strong form. Given an initial velocity field $\mathbf{u}_0$ that satisfies the incompressibility constraint ($\nabla \cdot \mathbf{u}_0 = 0$), we aim to find the velocity $\mathbf{u}$ and pressure $p$ such that
#
# \begin{equation}
# \left\{
# \begin{array}{ll}
# \rho\left (\dfrac{\partial{\mathbf{u}}}{\partial{t}} +  \mathbf{u} \cdot \nabla \mathbf{u}\right )
# - \nabla \cdot ( 2 \, \mu \boldsymbol{\varepsilon}(\mathbf{u})) + \nabla{p} = \mathbf{f} & \mbox{ in } \Omega \\
# & \\
# \nabla \cdot \mathbf{u} = 0  & \mbox{ in } \Omega \\
# & \\
# \mathbf{u} = \mathbf{u}_D & \mbox{ on } \Gamma_D \\
# & \\
# \left [-p\mathbf{I} + 2\,\mu\, \boldsymbol{\varepsilon}(\mathbf{u}) \right ] \cdot \check{\mathbf{n}} = \boldsymbol{\mathcal{F}} & \mbox{ on } \Gamma_N
# \end{array}
# \right.
# \end{equation}
# $~$
#
# where $\mathbf{u}_D$ is a given function on $\Gamma_D$, $\boldsymbol{\mathcal{F}}$ is a given function on $\Gamma_N$ and $\mathbf{f}$ are the body forces (e.g., $\mathbf{f} = -\rho \, g  \check{\mathbf{e}}_3$).
#
# The following comments are in order:
#
# * The stresses in the fluid are described by the Cauchy stress tensor
#
# \begin{equation}
# \boldsymbol{\sigma}(\mathbf{x},t) = -p(\mathbf{x},t) \mathbf{I} + \boldsymbol{\sigma}^*(\mathbf{x},t)
# \end{equation}
#
# which is the sum of a volumetric part
#
# \begin{equation}
# -p(\mathbf{x},t) \mathbf{I} =
# \begin{bmatrix}
# -p & 0 & 0 \\
# 0 & -p & 0 \\
# 0 & 0 & -p
# \end{bmatrix}
# \end{equation}
# and a deviatoric part
# \begin{equation}
# \boldsymbol{\sigma}^*(\mathbf{x},t)= 2 \, \mu \boldsymbol{\varepsilon}(\mathbf{u}) =
# \mu \left (\nabla{\mathbf{u}} + \nabla^{\intercal}{\mathbf{u}} \right)
# \end{equation}
#
# where $\mu$ is the dynamic viscosity of the fluid.
#
# * The pressure $p$ has no thermodynamic meaning for this problem, its
# sole role is to enforce the incompressibility constraint
#
# $$
# \nabla \cdot \mathbf{u} = 0
# $$

# %% [markdown]
# ## Solution strategy and variational formulation
#
# There are essentially two approaches to solve this problem, namely,
#
# * **Segregated**: typically, some variant of the Chorin's projection method, in which the problem is splitted into a
#     * Momentum predictor to find a velocity $\mathbf{u}^*$ ignoring the pressure term
#     * Poisson's pressure solver to find $p$
#     * Momentum corrector to find a velocity $\mathbf{u}$ that satisfies the incompressibility constraint
#
# * **Monolithic**: both fields $\mathbf{u}$ and $p$ are found at once, leading
# to an algebraic problem with saddle point structure
#
# In this tutorial, we will adopt the **monolithic** approach for simplicity and also to continue illustrating the use mixed function spaces. This approach is certainly the most appropriate for low Reynolds (Re $\ll 1$) numbers, wheareas the segregated approach is more convenient for Re $\gg 1$.

# %% [markdown]
# The variational formulation for this problem shares similarities with that of the Elasticity problem, however, we have additional terms to deal with.
# By multiplying by a sufficiently regular test function $\mathbf{v}$ belonging to the velocity space in the first equation and integrate by parts
# and, multiplying by a test function $q$ belonging to the pressure space
# in the second equation we obtain
#
# Find $(\mathbf{u},p) \in U_{\mathbf{g}} \times L^2(\Omega)$ such that
#
# \begin{eqnarray}
# \int_{\Omega}{\mathcal{G}_{\mathbf{u}} \cdot \mathbf{v} }\,dx +
# {\int_{\Omega}}{2\,\mu \boldsymbol{\varepsilon}(\mathbf{u}) : \boldsymbol{\varepsilon}(\mathbf{v}) }\,dx
#  - {\int_{\Omega}}{p\,\nabla \cdot \mathbf{v}}\,dx & = & {\int_{\Omega}}{\mathbf{f}\cdot \mathbf{v}}\,dx + {\int_{\Gamma_{\boldsymbol{\mathcal{F}}}}}{\boldsymbol{\mathcal{F}} \cdot \mathbf{v}}\,ds \\
# & &  \\
# {\int_{\Omega}}{q\,\nabla \cdot \mathbf{u}}\,dx & = &  0
# \end{eqnarray}
# $\forall (\mathbf{v},q) \in U_{\mathbf{0}} \times L^2(\Omega).$
#
# where $\mathcal{G}_{\mathbf{u}}  = \rho\left ({\partial_t{\mathbf{u}}} +  \mathbf{u} \cdot \nabla \mathbf{u}\right )~$ is the inertial term.
# $~$
#
# In abstract form:
#
# \begin{equation}
# \left \{
# \begin{array}{rlll}
# c(\mathbf{u};\mathbf{u}, \mathbf{v}) + {a}(\mathbf{u},\mathbf{v}) - b(\mathbf{v},p) & = & \ell(\mathbf{v}) & \forall \mathbf{v} \in U_{\mathbf{0}} \nonumber \\
# b(\mathbf{u},q) & = & 0 & \forall q\in L^2(\Omega) \nonumber
# \end{array}
# \right.
# \end{equation}
#
# where the form $c(\cdot ; \cdot, )$ corresponds to the inertial terms, $a(\cdot, \cdot)$ to the viscous terms and $b(\cdot, \cdot)$ to the pressure and continuity terms.
# $~$
#
# Adding everything as usual for the `FEniCSx` implementation
# $~$
#
# ---
# Find $(\mathbf{u}, p) \in W = U_{\mathbf{g}} \times Q$ such that
#
# $$
# B\left ( (\mathbf{u}, p),  (\mathbf{v}, q) \right) = L((\mathbf{v}, q))
# $$
#
# $\forall (\mathbf{v}, q) \in U_{\mathbf{0}} \times Q$ with
#
# ---

# %% [markdown]
# ## Finite element implementation

# %%
try:
    import gmsh
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/gmsh-install.sh" -O "/tmp/gmsh-install.sh" && bash "/tmp/gmsh-install.sh"
    import gmsh
    
try:
    import dolfinx
except ImportError:
    # !wget "https://fem-on-colab.github.io/releases/fenicsx-install-real.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh"
    import dolfinx

try:
    import pyvista
except ImportError:
    # !pip install - q piglet pyvirtualdisplay ipyvtklink pyvista panel
    # !apt-get - qq install xvfb
    import pyvista

# %%
from dolfinx import mesh, fem, io, plot, nls, log, cpp

from ufl import (derivative, SpatialCoordinate, FiniteElement, VectorElement, MixedElement, 
                 TestFunction, split, Identity, Measure, dx, ds, 
                 grad, nabla_grad, div, dot, inner, as_vector, FacetNormal)

import numpy as np
from mpi4py import MPI
from petsc4py.PETSc import ScalarType, Options
import matplotlib.pyplot as plt
import IPython

# %% [markdown]
# We will solve two problems in this tutorial:
#
# * The simple Poiseuille channel flow
#
# * The Flow around a circular obstacle
#
# The geometry for each case is created as in other tutorial we have done.
# Being a complex geometry, the second case requires a unstructured grid
# which take some additional programming efforts.
# $~$
#
# You have to select the case by setting the `simple_mesh` boolean variable
# below (`True` for the simple channel flow and `False` otherwise):

# %%
# Computational mesh 
simple_mesh = False

if(simple_mesh):
  Lx, Ly = 3.0, 1.0
  msh = mesh.create_rectangle(comm=MPI.COMM_WORLD,
                              points=((0.0, 0.0), (Lx, Ly)), n=(48, 16),
                              cell_type=mesh.CellType.triangle)
else:
  gmsh.initialize()
  L = 1.75
  H = 0.41
  Lx, Ly = L, H
  c_x = c_y =0.2
  r = 0.05
  gdim = 2
  mesh_comm = MPI.COMM_WORLD
  model_rank = 0
  
  fluid_marker = 1
  inlet_marker, outlet_marker, wall_marker, obstacle_marker = 2, 3, 4, 5

  if mesh_comm.rank == model_rank:
    rectangle = gmsh.model.occ.addRectangle(0,0,0, L, H, tag=1)
    obstacle = gmsh.model.occ.addDisk(c_x, c_y, 0, r, r)

    fluid = gmsh.model.occ.cut([(gdim, rectangle)], [(gdim, obstacle)])
    gmsh.model.occ.synchronize()

    volumes = gmsh.model.getEntities(dim=gdim)
    assert(len(volumes) == 1)
    gmsh.model.addPhysicalGroup(volumes[0][0], [volumes[0][1]], fluid_marker)
    gmsh.model.setPhysicalName(volumes[0][0], fluid_marker, "Fluid")

  inflow, outflow, walls, obstacle = [], [], [], []
  if mesh_comm.rank == model_rank:
    boundaries = gmsh.model.getBoundary(volumes, oriented=False)
    for boundary in boundaries:
        center_of_mass = gmsh.model.occ.getCenterOfMass(boundary[0], boundary[1])
        if np.allclose(center_of_mass, [0, H/2, 0]):
            inflow.append(boundary[1])
        elif np.allclose(center_of_mass, [L, H/2, 0]):
            outflow.append(boundary[1])
        elif np.allclose(center_of_mass, [L/2, H, 0]) or np.allclose(center_of_mass, [L/2, 0, 0]):
            walls.append(boundary[1])
        else:
            obstacle.append(boundary[1])

    gmsh.model.addPhysicalGroup(1, walls, wall_marker)
    gmsh.model.setPhysicalName(1, wall_marker, "Walls")
    gmsh.model.addPhysicalGroup(1, inflow, inlet_marker)
    gmsh.model.setPhysicalName(1, inlet_marker, "Inlet")
    gmsh.model.addPhysicalGroup(1, outflow, outlet_marker)
    gmsh.model.setPhysicalName(1, outlet_marker, "Outlet")
    gmsh.model.addPhysicalGroup(1, obstacle, obstacle_marker)
    gmsh.model.setPhysicalName(1, obstacle_marker, "Obstacle")

  res_min = r / 4.0
  if mesh_comm.rank == model_rank:
    distance_field = gmsh.model.mesh.field.add("Distance")
    gmsh.model.mesh.field.setNumbers(distance_field, "EdgesList", obstacle)
    threshold_field = gmsh.model.mesh.field.add("Threshold")
    gmsh.model.mesh.field.setNumber(threshold_field, "IField", distance_field)
    gmsh.model.mesh.field.setNumber(threshold_field, "LcMin", res_min)
    gmsh.model.mesh.field.setNumber(threshold_field, "LcMax", 0.08 * H)
    gmsh.model.mesh.field.setNumber(threshold_field, "DistMin", r)
    gmsh.model.mesh.field.setNumber(threshold_field, "DistMax", 2 * H)
    min_field = gmsh.model.mesh.field.add("Min")
    gmsh.model.mesh.field.setNumbers(min_field, "FieldsList", [threshold_field])
    gmsh.model.mesh.field.setAsBackgroundMesh(min_field)

  if mesh_comm.rank == model_rank:
    gmsh.option.setNumber("Mesh.Algorithm", 6)
    gmsh.model.mesh.generate(gdim)

  msh, subdomains, boundaries = io.gmshio.model_to_mesh(gmsh.model, mesh_comm, model_rank, gdim=2)
  gmsh.finalize()

tdim = msh.topology.dim
num_cells = msh.topology.index_map(tdim).size_local
h = cpp.mesh.h(msh, tdim, range(num_cells))
hmin = h.min()

print(f"|> Mesh created with hmin={h.min():f}, hmax={h.max():f} and {num_cells:d} total elements")
# Out:
# |> Mesh created with hmin=0.010504, hmax=0.044935 and 3831 total elements

# %% [markdown]
# As usual, we use `pyvista` to visualize the mesh:

# %%
def plot_mesh(mesh, cell_values=None, filename="file.html"):
    pyvista.start_xvfb()
    grid = pyvista.UnstructuredGrid(*plot.create_vtk_mesh(mesh))
    plotter = pyvista.Plotter(notebook=True, window_size=[500,500])

    if cell_values is not None:
        min_ = cell_values.x.array.min()
        max_ = cell_values.x.array.max()
        grid.cell_data["cell_values"] = cell_values.x.array
        viridis = plt.cm.get_cmap("viridis", 25)
        plotter.add_mesh(grid, cmap=viridis, show_edges=True, clim=[min_, max_])
    else:
        plotter.add_mesh(grid, show_edges=True)
    
    plotter.camera.zoom(2.0)
    plotter.view_xy()
    plotter.export_html(filename, backend="pythreejs")
    plotter.close()

with io.XDMFFile(MPI.COMM_WORLD, "mymesh.xdmf", "w") as xdmf:
    xdmf.write_mesh(msh)

plot_mesh(msh, cell_values=None, filename="mesh.html")
IPython.display.HTML(filename="mesh.html")
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>PyVista</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@^0.20.1/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "562a59db102c433293941fe44ad01449": {
#       "model_name": "RendererModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "_alpha": true,
#         "_dom_classes": [],
#         "_height": 500,
#         "_width": 500,
#         "camera": "IPY_MODEL_c436dfa66d064aa39f4aeebded8adfa3",
#         "clearOpacity": 0.0,
#         "clippingPlanes": [],
#         "controls": [
#           "IPY_MODEL_10a5116fe51d41b89665586b374c1366"
#         ],
#         "layout": "IPY_MODEL_f4a578709f4d4c0dbf4ab6f6a11efd7f",
#         "scene": "IPY_MODEL_d761033d129a45258dd323cfa829a331",
#         "shadowMap": "IPY_MODEL_e21e87fc2f764c5aba156a07644b0757"
#       }
#     },
#     "c436dfa66d064aa39f4aeebded8adfa3": {
#       "model_name": "PerspectiveCameraModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [
#           "IPY_MODEL_c8a39e47e6924fe7af5498ceaff4c1af",
#           "IPY_MODEL_5fe0aef3e1444411a50825f8008a866d",
#           "IPY_MODEL_4ecabc86f69d483880034d13735c9318",
#           "IPY_MODEL_d65d8f20364b44a789424b780a545562",
#           "IPY_MODEL_911117956e9c47b0a8da9b55aaeab9ef"
#         ],
#         "far": 347228.50313492434,
#         "fov": 30.0,
#         "near": 0.01,
#         "position": [
#           0.0,
#           0.0,
#           3.4722850313492435
#         ]
#       }
#     },
#     "c8a39e47e6924fe7af5498ceaff4c1af": {
#       "model_name": "DirectionalLightModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "intensity": 0.25,
#         "position": [
#           0.0,
#           0.0,
#           100000.0
#         ],
#         "shadow": "uninitialized",
#         "target": "uninitialized"
#       }
#     },
#     "5fe0aef3e1444411a50825f8008a866d": {
#       "model_name": "DirectionalLightModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "color": "#fffcf4",
#         "intensity": 0.75,
#         "position": [
#           11161.889704894966,
#           76604.4443118978,
#           63302.222155948904
#         ],
#         "shadow": "uninitialized",
#         "target": "uninitialized"
#       }
#     },
#     "4ecabc86f69d483880034d13735c9318": {
#       "model_name": "DirectionalLightModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "color": "#f5f7ff",
#         "intensity": 0.25,
#         "position": [
#           -4494.345552754778,
#           -96592.58262890684,
#           25488.700224417877
#         ],
#         "shadow": "uninitialized",
#         "target": "uninitialized"
#       }
#     },
#     "d65d8f20364b44a789424b780a545562": {
#       "model_name": "DirectionalLightModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "intensity": 0.21428571428571427,
#         "position": [
#           93969.26207859084,
#           0.0,
#           -34202.01433256687
#         ],
#         "shadow": "uninitialized",
#         "target": "uninitialized"
#       }
#     },
#     "911117956e9c47b0a8da9b55aaeab9ef": {
#       "model_name": "DirectionalLightModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "intensity": 0.21428571428571427,
#         "position": [
#           -93969.26207859084,
#           0.0,
#           -34202.01433256687
#         ],
#         "shadow": "uninitialized",
#         "target": "uninitialized"
#       }
#     },
#     "10a5116fe51d41b89665586b374c1366": {
#       "model_name": "OrbitControlsModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "controlling": "IPY_MODEL_c436dfa66d064aa39f4aeebded8adfa3",
#         "maxAzimuthAngle": 1e+20,
#         "maxDistance": 1e+20,
#         "maxZoom": 1e+20,
#         "minAzimuthAngle": -1e+20
#       }
#     },
#     "f4a578709f4d4c0dbf4ab6f6a11efd7f": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "1.2.0",
#       "state": {}
#     },
#     "d761033d129a45258dd323cfa829a331": {
#       "model_name": "SceneModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "background": "#4c4c4c",
#         "children": [
#           "IPY_MODEL_c926e9e641fa424396ed2a5304aa1f0b",
#           "IPY_MODEL_411af4e9bacd4a2a9aef9a0966f8643a",
#           "IPY_MODEL_c436dfa66d064aa39f4aeebded8adfa3"
#         ],
#         "fog": null,
#         "overrideMaterial": null
#       }
#     },
#     "c926e9e641fa424396ed2a5304aa1f0b": {
#       "model_name": "LineSegmentsModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "geometry": "IPY_MODEL_34a4e359cfa24736b957385cbcaf1455",
#         "material": "IPY_MODEL_5fb225223f7e42d2b9dd37e752dc2ff8",
#         "position": [
#           -0.875,
#           -0.205,
#           -0.0
#         ]
#       }
#     },
#     "34a4e359cfa24736b957385cbcaf1455": {
#       "model_name": "BufferGeometryModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "_ref_geometry": null,
#         "attributes": {
#           "position": "IPY_MODEL_85d38bcaa8a845048fb58deafb7ae6f0",
#           "index": "IPY_MODEL_5250237491244dc1944e24c65d4561f7"
#         },
#         "index": null,
#         "morphAttributes": {},
#         "userData": {}
#       }
#     },
#     "85d38bcaa8a845048fb58deafb7ae6f0": {
#       "model_name": "BufferAttributeModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "array": {
#           "shape": [
#             2022,
#             3
#           ],
#           "dtype": "float32"
#         }
#       },
#       "buffers": [
#         {
#           "encoding": "base64",
#           "path": [
#             "array",
#             "buffer"
#           ],
#           "data": "..."
#         }
#       ]
#     },
#     "5250237491244dc1944e24c65d4561f7": {
#       "model_name": "BufferAttributeModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "array": {
#           "shape": [
#             11706
#           ],
#           "dtype": "uint16"
#         }
#       },
#       "buffers": [
#         {
#           "encoding": "base64",
#           "path": [
#             "array",
#             "buffer"
#           ],
#           "data": "..."
#         }
#       ]
#     },
#     "5fb225223f7e42d2b9dd37e752dc2ff8": {
#       "model_name": "LineBasicMaterialModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "clippingPlanes": [],
#         "color": "#000000",
#         "defines": null
#       }
#     },
#     "411af4e9bacd4a2a9aef9a0966f8643a": {
#       "model_name": "MeshModel",
#       "model_module": "jupyter-threejs",
#       "model_module_version": "^2.1.0",
#       "state": {
#         "children": [],
#         "geometry": "IPY_MODEL_34143172eaf347fc882237618bea2afa",
#         "material": "IPY_MODEL_f84397ee55344e0e898a96dfddc09a46",
#         "morphTargetInfluences": [],
#         "position": [
#           -0.875,
#           -0.205,
#           -0.0
#         ]
#       }
#     },
#     "34143172eaf347fc882237618bea2afa": {
#       "model_name": "BufferGeometryModel",
#       "

# %% [markdown]
# ## Finite element spaces
#
# Now, we reach a critical point in the implementation, which is the choice of the *discrete basis* (i.e., finite element spaces) for the **velocity** and **pressure** unknowns, which is not a trivial issue as in previous cases.
#
# In a constrained problem like this one, for the discrete formulation
# to be well-posed, we need the velocity space $U_h \subset [H^1(\Omega)]^d$ and the pressure space $Q_h \subset L^2(\Omega)$ to satisfy a compatibility requirement, such that the famous LBB (**Ladyzhenskaya-Babuška-Brezzi**) condition is full-filled. Otherwise, some numerical artifacts known as
# *spurious modes* will emerge. A complete explanation of such condition is out of the scope of this course. Another alternative is to adopt
# a stabilized formulation, such as GLS, ASGS, VMS, etc.m but this is left for a more advanced course.
# $~$
#
# One possible choice of a stable finite element pair is the *mini*-element
# ($P_1^+$-$P_1$). One very popular and simple choice is the **Taylor-Hood** element. Given a finite element conforming mesh $\mathcal{T}_h$ we choose
#
# $$
# U(\mathcal{T}_h) = U_h = \{\mathbf{v} \in [H^1(\Omega)]^d,~\mathbf{v}|_E \in [P_2(E)]^d \, \forall E \in \mathcal{T}_h\}
# $$
#
# $$
# Q(\mathcal{T}_h) = Q_h = \{\mathbf{v} \in H^1(\Omega),~\mathbf{v}|_E \in P_1(E) \, \forall E \in \mathcal{T}_h\}
# $$
#
# which is implemented in `FEniCSx` as:

# %%
# Create an element for each field
degree_u = 2
P2 = VectorElement("CG", msh.ufl_cell(), degree_u)

degree_p = 1
P1 = FiniteElement("CG",  msh.ufl_cell(), degree_p)

# the Taylor-Hood element 
TH  = MixedElement([P2, P1])

# and the corresponding global space of functions
W = fem.FunctionSpace(msh, TH)

U, Umap = W.sub(0).collapse()
Q, Qmap = W.sub(1).collapse()

# %% [markdown]
# For the $P_2$ Lagrangian finite element space associated to a partition $\mathcal{T}_h$, the degrees of freedom (dofs) are the function values at:
#
# * Vertices of the triangular elements
# * Mid-points of edges
#
# A discrete function $\mathbf{u}_h\in U_h$ is written as
#
# $$
# \mathbf{u}_h = \sum_{i=1}^{dim{U_h}}{a_j \mathbf{N}_j}
# $$
#
# where $\{\mathbf{N}_j\}_{j=1}^{dim{U_h}}$ are a set of basis functions for $U_h$. For the $P_1$ Lagrangian space, the dofs are simply the function values
# at the vertices of the triangulation, a discrete function
# $\mathbf{p}_h\in Q_h$ is written as
#
# $$
# p_h = \sum_{i=1}^{dim{Q_h}}{p_j \psi_j}
# $$
# where $\{\psi_j\}_{j=1}^{dim{U_h}}$ are a set of basis functions for $Q_h$.
#
# Therefore, the total dimension of the system to be solved is
#
# $$
# dim = dim{U_h} + dim{Q_h}
# $$
#
# so the global vector of unknowns $\boldsymbol{\mathsf{X}} = [\boldsymbol{\mathsf{U}}, \boldsymbol{\mathsf{P}}]^{\intercal} \in \mathbb{R}^{dim}$,
# where $\boldsymbol{\mathsf{U}} \in \mathbb{R}^{dimU_h}$ and $\boldsymbol{\mathsf{P}} \in \mathbb{R}^{dimP_h}$.

# %%
# Create and auxliary function
faux = fem.Function(W)
dimtot = faux.x.array.shape[0]
dimU = faux.sub(0).collapse().x.array.shape[0]
dimP = faux.sub(1).collapse().x.array.shape[0]
print(f"|> Triangular mesh created having {num_cells:d} elements.\n|> #dofs = dimTotal = {dimtot:d} = dimU + dimP = {dimU:d} + {dimP:d}")
# Out:
# |> Triangular mesh created having 3831 elements.
# |> #dofs = dimTotal = 17772 = dimU + dimP = 15750 + 2022

# %% [markdown]
# ## Boundary conditions
#
# Implementation of the Dirichlet or essential conditions are also a critical issue to as the discretization.
#
# For both problems to be solved, namely, the Poiseuille and the obtacle in a channel, we impose **non-slip** Dirichlet conditions for velocity at the *Top* and *Bottom* walls and an inlet velocity profile at the *left* wall, which is given by
# $~$
#
# $$
# \mathbf{u}_{inlet}(x=0,y) = 2 U_{\max} H (H - y) / H^2
# $$
#
# where $H$ is the inlet height. The outlet (*right* wall) is left open,
# so as the fluid is free to leave (stress-free).

# %%
# Boundary values
Umax = 1
def u_inlet(x):
    return (2*Umax*x[1]*(Ly-x[1])/Ly**2, np.zeros_like(x[0]))

def u_noslip(x):
    return (np.zeros_like(x[0]), np.zeros_like(x[0]))

if(simple_mesh):

  def walls(x):
    return np.logical_or(np.isclose(x[1],0), np.isclose(x[1],Ly))

  def inflow(x):
    return np.isclose(x[0], 0)

  def outflow(x):
    return np.isclose(x[0], Lx)

  #------------
  wall_dofs = fem.locate_dofs_geometrical((W.sub(0), U), walls)
  u_ns = fem.Function(U)
  u_ns.interpolate(u_noslip)
  bc_noslip = fem.dirichletbc(u_ns, wall_dofs, W.sub(0))

  #------------
  inflow_dofs = fem.locate_dofs_geometrical((W.sub(0), U), inflow)
  u_in = fem.Function(U)
  u_in.interpolate(u_inlet)
  bc_inflow = fem.dirichletbc(u_in, inflow_dofs, W.sub(0))

  # Collect all bcs
  bcs = [bc_noslip, bc_inflow]
else:
  fdim = 1

  # Inlet
  inflow_dofs = fem.locate_dofs_topological((W.sub(0), U), fdim, boundaries.find(inlet_marker))
  u_in = fem.Function(U)
  u_in.interpolate(u_inlet)
  bc_inflow = fem.dirichletbc(u_in, inflow_dofs, W.sub(0))

  # Noslip walls
  wall_dofs = fem.locate_dofs_topological((W.sub(0), U), fdim, boundaries.find(wall_marker))
  obs_dofs = fem.locate_dofs_topological((W.sub(0), U), fdim, boundaries.find(obstacle_marker))
  u_ns = fem.Function(U)
  u_ns.interpolate(lambda x: u_noslip(x))
  bc_walls = fem.dirichletbc(u_ns, wall_dofs, W.sub(0))
  bc_obstacle = fem.dirichletbc(u_ns, obs_dofs, W.sub(0))
  
  # Collect all bcs
  bcs = [bc_inflow, bc_obstacle, bc_walls]

# %% [markdown]
# ## Fully discrete problem
#
# We finally provide the time discretization for this problem.
# Ley us begin by discretizing the time derivative as
#
# $$
# \left. \dfrac{\partial{\mathbf{u}}}{\partial{t}}\right |_{[t_n,t_{n+1}]} \approx \dfrac{\mathbf{u}^{n+1} - \mathbf{u}^n}{\Delta{t}}
# $$
#
# Now, we must choose at which time each term is
#
# \begin{eqnarray}
# \int_{\Omega}{\rho\left (\dfrac{\mathbf{u}^{n+1} - \mathbf{u}^n}{\Delta{t}} +  \mathbf{u}^{n+\gamma_1} \cdot \nabla \mathbf{u}^{n+\gamma_2}\right ) \cdot \mathbf{v} }\,dx +
# {\int_{\Omega}}{2\,\mu \boldsymbol{\varepsilon}(\mathbf{u}^{n+\theta}) : \boldsymbol{\varepsilon}(\mathbf{v}) }\,dx
# & = & \\
# - {\int_{\Omega}}{p^{n+1}\,\nabla \cdot \mathbf{v}}\,dx = {\int_{\Omega}}{\mathbf{f}^{n+\theta}\cdot \mathbf{v}}\,dx + {\int_{\Gamma_{\boldsymbol{\mathcal{F}}}}}{\boldsymbol{\mathcal{F}^{n+\theta}} \cdot \mathbf{v}}\,ds \\
# & &  \\
# {\int_{\Omega}}{q\,\nabla \cdot \mathbf{u}^{n+1}}\,dx  & = & 0
# \end{eqnarray}
#
# The algebraic problem would look like
#
# $$
# \begin{bmatrix}
# A_{\mathbf{u}\mathbf{u}} & B_{\mathbf{u}p} \\
# C_{p\mathbf{u}} & 0
# \end{bmatrix}
# \begin{bmatrix}
# \mathsf{U}^{n+1} \\
# \mathsf{P}^{n+1}
# \end{bmatrix}
# =
# \begin{bmatrix}
# \mathsf{F} \\
# \mathsf{0}
# \end{bmatrix}
# $$
#
# where the rhs contains contributions from the forcing terms as
# well as from the previous solution $\mathsf{U}^{n}$ and the boundary
# conditions.
#
# ---
#
# Some comments are in order:
#
# * The pressure and continuity equation and always treated implicitly
#
# * Depending on the choice for $\gamma_1$ and $\gamma_2$ we may end up with a linearized problem or a nonlinear one, for which, Newton-Raphson, Picard or fixed-point iterations must be applied. Below, we create a Newton solver using
# the two functions
#
#       problem = fem.petsc.NonlinearProblem(...)
#       solver = nls.petsc.NewtonSolver(MPI.COMM_WORLD, problem)
#
# (*Notice that a nonlinear solver serves both, linear and nonlinear problems, except that in the former case it should converge in 1 single iteration)*
#
# * Depending on the choice for $\theta$ we end up with an implicit or explicit formulation.
# The latter case requiring the time step to be bounded by
#
# $$
# \Delta{t}_{\mu} < C_{\mu} \dfrac{\rho \, h^2}{\mu}
# $$
# for some constant $C_{\mu}$. For the implicit case we
# usually take $\theta = 1$ or $\theta = 0.5$ (Crank-Nicolson).
#
# * In a totally explicit treatment of advective terms, advection is stabilized by viscosity if the time step is bounded by
#
# $$
# \Delta{t}_{a} < \dfrac{C_a\mu}{\rho \, (\mathbf{u} \cdot \mathbf{u})}
# $$
#
# * If we consider the Reynold number Re$=\dfrac{\rho \, U \, H}{\mu}$ and
# nondimensionalize time as $\bar{t} = \dfrac{t U}{H}$, we see that
# $$
# \bar{\Delta{t}}_{a} = \dfrac{C_a}{\mbox{Re}} \xrightarrow[\mbox{Re} ~\rightarrow~ \infty]{} 0~~~~~\mbox{and}~~~~~
# \bar{\Delta{t}}_{\mu} = C_{\mu} \dfrac{h^2}{H^2}\mbox{Re}\xrightarrow[\mbox{Re} ~\rightarrow~ 0]{} 0,
# $$
#
# * For low Re, its is convenient an implicit scheme for the viscous terms,
# since the restriction scales as $\mathcal{O}(h^2)$.
#
# * For high Re, the time step should also be controlled, however, stability also
# depends on the choice of the advection scheme.
#
#
# ---

# %%
# Define numerical and material parameters

# Time-stepping parameters
T = 10
num_steps = 1000
dt = T/num_steps
Dt = fem.Constant(msh, ScalarType(dt))

# Time parameter for viscous term
theta = fem.Constant(msh, ScalarType(0.5))

# Time parameter for convective velocity
gamma = fem.Constant(msh, ScalarType(0.0))

# Body force
f = fem.Constant(msh, ScalarType((0,0)))

# Viscosity
muf = 0.001
mu = fem.Constant(msh, ScalarType(muf))

# Density
rhof = 3.0
rho = fem.Constant(msh, ScalarType(rhof))

print("-------------------------------")
print("--- To have as a reference ")
print(f"|> Time step: dt = {dt:f}")
print(f"|> dt_adv = {4*muf/(rhof*Umax**2):f}")
print(f"|> dt_vis = {0.25*rhof*hmin**2/muf:f}")
print(f"|> dt_cfl = {hmin/Umax:f}")
print("-------------------------------")

if(simple_mesh):
  Re = Ly*rhof*Umax/muf
else:
  Re = 2*r*Umax*rhof/muf

print("-------------------------------")
print(f"|> Reynolds number: Re = {Re:0.1f}")
print("-------------------------------")
# Out:
# -------------------------------
# --- To have as a reference
# |> Time step: dt = 0.010000
# |> dt_adv = 0.001333
# |> dt_vis = 0.082758
# |> dt_cfl = 0.010504
# -------------------------------
# -------------------------------
# |> Reynolds number: Re = 300.0
# -------------------------------

# %%
# Strain-rate tensor
def epsilon(u):
    return 0.5*(nabla_grad(u) + nabla_grad(u).T)

# Current solution
w = fem.Function(W)

# Solution at previous time
w_n = fem.Function(W)

dw = TestFunction(W)

(u, p) = split(w)
(v, q) = split(dw)

w_n.sub(0).interpolate(u_inlet)
(u_n, p_n) = split(w_n) # é o split do uf

utheta = theta*u + (1-theta)*u_n
ugamma = gamma*u + (1-gamma)*u_n

# Momentum residual
Fu  = rho*inner((u - u_n) / Dt, v) * dx
Fu += rho*inner(dot(ugamma, nabla_grad(utheta)), v) * dx
Fu += inner(2*mu*epsilon(utheta), epsilon(v)) * dx - p * div(v) * dx
Fu -= inner(f, v)*dx
# Continuity residual
Fp = div(u) * q * dx
# Total residual
Res = Fu + Fp

# Setting the Non-linear solver
Jac = derivative(Res, w)
problem = fem.petsc.NonlinearProblem(Res, u=w, bcs=bcs, J=Jac)
solver = nls.petsc.NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-6
solver.max_it = 10
solver.report = True

# Setting linear solver options to be used at each Newton iteration
ksp = solver.krylov_solver
opts = Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "preonly"
opts[f"{option_prefix}pc_type"] = "lu"
opts[f"{option_prefix}ksp_monitor"] = None
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
ksp.setFromOptions()

# %%
# Loop over time steps
t = 0

# Save initial condition
xdmfu = io.XDMFFile(msh.comm, "vel.xdmf", "w")
xdmfu.write_mesh(msh)
upl = w_n.sub(0).collapse()
upl.name = "Velocity"
xdmfu.write_function(upl, t)

xdmfp = io.XDMFFile(msh.comm, "pres.xdmf", "w")
xdmfp.write_mesh(msh)
ppl = w_n.sub(1).collapse()
ppl.name = "Pressure"
xdmfp.write_function(ppl, t)

freq_out = 50
for i in range(num_steps):
    
    t += dt

    print("-------------------------------")
    print(f"|> Solving at time= {t:f}\n")
    log.set_log_level(log.LogLevel.INFO)
    niters, converged = solver.solve(w)
    assert(converged)
    print(f"Number of interations= {niters:d}")

    # Update the previous solution with the last computed value
    w_n.x.array[:] = w.x.array[:]
    w_n.x.scatter_forward()

    # Save the last computed solution
    if(i % freq_out== 0):
      upl = w_n.sub(0).collapse()
      upl.name = "Velocity"
      xdmfu.write_function(upl, t)
      ppl = w_n.sub(1).collapse()
      ppl.name = "Pressure"
      xdmfp.write_function(ppl, t)

# End loop over time steps
xdmfu.close()
xdmfp.close()

from google.colab import files
files.download('vel.xdmf')
files.download('vel.h5')
files.download('pres.xdmf')
files.download('pres.h5')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# -------------------------------
# |> Solving at time= 5.010000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.448517947115e-02
#   1 KSP Residual norm 4.554546009937e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.159474544325e-17
#   1 KSP Residual norm 3.974897064232e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.020000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.448678153356e-02
#   1 KSP Residual norm 4.699836972514e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.354624119976e-17
#   1 KSP Residual norm 2.633552737254e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.030000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.449281884698e-02
#   1 KSP Residual norm 5.002118469364e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.324591427627e-17
#   1 KSP Residual norm 2.328982127151e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.040000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.450260739542e-02
#   1 KSP Residual norm 4.679076822003e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.125717446554e-17
#   1 KSP Residual norm 3.397339206357e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.050000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.451505396331e-02
#   1 KSP Residual norm 5.016373324837e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.877301485362e-17
#   1 KSP Residual norm 2.522791845836e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.060000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.452910233519e-02
#   1 KSP Residual norm 4.760897296958e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.532585597428e-17
#   1 KSP Residual norm 2.681057656657e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.070000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.454434712134e-02
#   1 KSP Residual norm 4.882425909513e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.252235357094e-17
#   1 KSP Residual norm 3.108280229837e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.080000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.456116489630e-02
#   1 KSP Residual norm 4.933413179624e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.228468479772e-17
#   1 KSP Residual norm 3.003629029014e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.090000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.458007221346e-02
#   1 KSP Residual norm 4.954126754781e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.107420558824e-17
#   1 KSP Residual norm 2.358853088218e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.100000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.460098621825e-02
#   1 KSP Residual norm 4.785956342266e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.123746927549e-17
#   1 KSP Residual norm 3.746223983561e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.110000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.462326885409e-02
#   1 KSP Residual norm 5.033393329135e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.047038020230e-17
#   1 KSP Residual norm 7.217370873640e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.120000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.464649505069e-02
#   1 KSP Residual norm 5.040183840734e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.917179089485e-17
#   1 KSP Residual norm 9.941905505886e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.130000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.467098497081e-02
#   1 KSP Residual norm 4.974978870283e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.082963775686e-17
#   1 KSP Residual norm 2.843678731002e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.140000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.469740318878e-02
#   1 KSP Residual norm 4.799131847118e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.264311712008e-17
#   1 KSP Residual norm 1.516336806738e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.150000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.472577420119e-02
#   1 KSP Residual norm 4.885740074311e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.088635901730e-17
#   1 KSP Residual norm 2.244183166660e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.160000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.475484568167e-02
#   1 KSP Residual norm 4.893772181324e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.391997542328e-17
#   1 KSP Residual norm 9.303920348068e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.170000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.478232277469e-02
#   1 KSP Residual norm 4.831102267268e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.109606463330e-17
#   1 KSP Residual norm 2.471766271044e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.180000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.480572553226e-02
#   1 KSP Residual norm 4.960363487479e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.077616465046e-17
#   1 KSP Residual norm 9.443125929864e-32
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.190000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.482327009328e-02
#   1 KSP Residual norm 4.892287073635e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.073119177968e-17
#   1 KSP Residual norm 4.554182305082e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.200000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.483432005056e-02
#   1 KSP Residual norm 4.818288347480e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.875943405622e-17
#   1 KSP Residual norm 1.820413177189e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.210000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.483925461703e-02
#   1 KSP Residual norm 4.871045297644e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.320282212458e-17
#   1 KSP Residual norm 1.771114849267e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.220000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.483889804900e-02
#   1 KSP Residual norm 4.835351386030e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.752822900692e-17
#   1 KSP Residual norm 2.227077799979e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.230000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.483391973444e-02
#   1 KSP Residual norm 4.912105708515e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.177315823592e-17
#   1 KSP Residual norm 9.596159316060e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.240000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.482466236426e-02
#   1 KSP Residual norm 4.927628593451e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.121990849767e-17
#   1 KSP Residual norm 1.365880193757e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.250000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.481154797300e-02
#   1 KSP Residual norm 4.886760185254e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.090551902869e-17
#   1 KSP Residual norm 2.629826392137e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.260000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.479574859638e-02
#   1 KSP Residual norm 4.950222517311e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.419311192323e-17
#   1 KSP Residual norm 3.991781657676e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.270000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.477957395638e-02
#   1 KSP Residual norm 5.054368125297e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.205036076856e-17
#   1 KSP Residual norm 4.329006934288e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.280000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.476621736620e-02
#   1 KSP Residual norm 4.980172777882e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.205941548187e-17
#   1 KSP Residual norm 1.140716333210e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.290000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.475896352216e-02
#   1 KSP Residual norm 4.810182247170e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.163592819329e-17
#   1 KSP Residual norm 1.353871316415e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.300000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.476034507586e-02
#   1 KSP Residual norm 5.035624420080e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.972145359382e-17
#   1 KSP Residual norm 7.521729684561e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.310000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.477174679065e-02
#   1 KSP Residual norm 4.924021155212e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.093398710827e-17
#   1 KSP Residual norm 1.370623223070e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.320000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.479358134657e-02
#   1 KSP Residual norm 5.061170551763e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.282174476926e-17
#   1 KSP Residual norm 2.008226683715e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.330000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.482571576803e-02
#   1 KSP Residual norm 4.917850910854e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.164301824358e-17
#   1 KSP Residual norm 1.790935677150e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.340000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.486772549986e-02
#   1 KSP Residual norm 5.032364160958e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.075351032740e-17
#   1 KSP Residual norm 7.730802654172e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.350000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.491884982649e-02
#   1 KSP Residual norm 4.838938381079e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.030707191187e-17
#   1 KSP Residual norm 6.679181986140e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.360000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.497779513489e-02
#   1 KSP Residual norm 4.924150550576e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.036533366774e-17
#   1 KSP Residual norm 1.164059663517e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.370000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.504246816588e-02
#   1 KSP Residual norm 5.094080436292e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.921951986528e-17
#   1 KSP Residual norm 2.118038497916e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.380000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.510964119838e-02
#   1 KSP Residual norm 4.986660495027e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.238499686896e-17
#   1 KSP Residual norm 1.388244129938e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.390000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.517486212334e-02
#   1 KSP Residual norm 5.048160271648e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.267096106524e-17
#   1 KSP Residual norm 7.938736374143e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.400000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.523319483194e-02
#   1 KSP Residual norm 5.293362905418e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.164773468827e-17
#   1 KSP Residual norm 2.523218133410e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.410000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.528080758193e-02
#   1 KSP Residual norm 4.985799127937e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.315689850316e-17
#   1 KSP Residual norm 1.876954340365e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.420000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.531635789509e-02
#   1 KSP Residual norm 5.141905781005e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.167504626442e-17
#   1 KSP Residual norm 1.094461306314e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.430000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.534099935163e-02
#   1 KSP Residual norm 5.089469276721e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.016919597314e-17
#   1 KSP Residual norm 2.332311695245e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.440000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.535712545324e-02
#   1 KSP Residual norm 4.857036497052e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.019176031927e-17
#   1 KSP Residual norm 2.581594840835e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.450000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.536715244355e-02
#   1 KSP Residual norm 5.138291141988e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.161036511535e-17
#   1 KSP Residual norm 3.872561509988e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.460000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.537322387790e-02
#   1 KSP Residual norm 5.007757083500e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.152092224242e-17
#   1 KSP Residual norm 1.335796205353e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.470000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.537738982875e-02
#   1 KSP Residual norm 5.135769989338e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.043360393161e-17
#   1 KSP Residual norm 1.622214031553e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.480000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.538145164230e-02
#   1 KSP Residual norm 5.173680604098e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.273146474924e-17
#   1 KSP Residual norm 1.807812320917e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.490000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.538658843198e-02
#   1 KSP Residual norm 5.300497066053e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.371198685436e-17
#   1 KSP Residual norm 1.312205883712e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.500000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.539351751585e-02
#   1 KSP Residual norm 5.012766140009e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.117007458351e-17
#   1 KSP Residual norm 3.365743020197e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.510000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.540325629861e-02
#   1 KSP Residual norm 5.055011642085e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.187136484992e-17
#   1 KSP Residual norm 7.056442785944e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.520000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.541753821501e-02
#   1 KSP Residual norm 4.912554927814e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.035802315677e-17
#   1 KSP Residual norm 1.883599640242e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.530000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.543810402138e-02
#   1 KSP Residual norm 5.144740230406e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.021761856399e-17
#   1 KSP Residual norm 2.628893389312e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.540000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.546537027331e-02
#   1 KSP Residual norm 5.012979788147e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.273284242252e-17
#   1 KSP Residual norm 1.357235247110e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.550000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.549783977769e-02
#   1 KSP Residual norm 5.132204810948e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.243948588158e-17
#   1 KSP Residual norm 2.073658690624e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.560000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.553298904117e-02
#   1 KSP Residual norm 5.114760079191e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.201587775405e-17
#   1 KSP Residual norm 2.224471761003e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.570000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.556886450062e-02
#   1 KSP Residual norm 4.968804659448e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.943653614472e-17
#   1 KSP Residual norm 1.323595655201e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.580000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560484967840e-02
#   1 KSP Residual norm 5.125105094396e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.178353160197e-17
#   1 KSP Residual norm 9.793946593687e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.590000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.564088967107e-02
#   1 KSP Residual norm 5.088298892669e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.189930061344e-17
#   1 KSP Residual norm 1.039063985501e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.600000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567605744697e-02
#   1 KSP Residual norm 5.059759118576e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.071626897382e-17
#   1 KSP Residual norm 4.029939448021e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.610000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570802848795e-02
#   1 KSP Residual norm 5.133563426257e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.046658793948e-17
#   1 KSP Residual norm 4.372176536939e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.620000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.573404006605e-02
#   1 KSP Residual norm 4.979437377703e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.981580172645e-17
#   1 KSP Residual norm 7.800071813441e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.630000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.575232822594e-02
#   1 KSP Residual norm 5.214403377057e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.099701898631e-17
#   1 KSP Residual norm 1.974079757269e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.640000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.576260508397e-02
#   1 KSP Residual norm 5.009801108922e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.284630539191e-17
#   1 KSP Residual norm 1.801075982404e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.650000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.576528352301e-02
#   1 KSP Residual norm 5.243728056283e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.943862843160e-17
#   1 KSP Residual norm 9.513210346418e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.660000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.576053643929e-02
#   1 KSP Residual norm 5.189528101815e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.184500597352e-17
#   1 KSP Residual norm 3.292456730095e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.670000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574836250020e-02
#   1 KSP Residual norm 4.891652101807e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.044743613402e-17
#   1 KSP Residual norm 1.211468785843e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.680000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572958843834e-02
#   1 KSP Residual norm 5.144958569938e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.992199287692e-17
#   1 KSP Residual norm 1.387991132974e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.690000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570658596756e-02
#   1 KSP Residual norm 5.079088033585e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.054098537098e-17
#   1 KSP Residual norm 5.542694455657e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.700000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.568267422992e-02
#   1 KSP Residual norm 5.014787403456e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.953631147890e-17
#   1 KSP Residual norm 3.876524738468e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.710000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566050421653e-02
#   1 KSP Residual norm 5.150937491542e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.238119612543e-17
#   1 KSP Residual norm 8.509214106838e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.720000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.564080977016e-02
#   1 KSP Residual norm 5.125420725562e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.218864410419e-17
#   1 KSP Residual norm 2.930452084910e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.730000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.562264369480e-02
#   1 KSP Residual norm 5.065466305226e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.182282278508e-17
#   1 KSP Residual norm 5.061897353470e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.740000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560482914694e-02
#   1 KSP Residual norm 5.272409930557e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.039736351256e-17
#   1 KSP Residual norm 8.756439003269e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.750000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.558721550416e-02
#   1 KSP Residual norm 5.035890312850e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.854007244859e-17
#   1 KSP Residual norm 1.570586820517e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.760000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.557059231755e-02
#   1 KSP Residual norm 5.266620020634e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.249875181227e-17
#   1 KSP Residual norm 2.857170006957e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.770000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.555553626561e-02
#   1 KSP Residual norm 5.172099683387e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.104054775260e-17
#   1 KSP Residual norm 2.110113526744e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.780000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.554159041148e-02
#   1 KSP Residual norm 5.140034293916e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.883339030594e-17
#   1 KSP Residual norm 3.576734978863e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.790000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.552781960452e-02
#   1 KSP Residual norm 4.978617751229e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.171405006060e-17
#   1 KSP Residual norm 1.581282705380e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.800000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.551430688738e-02
#   1 KSP Residual norm 5.053158572006e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.026879580146e-17
#   1 KSP Residual norm 1.630584202229e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.810000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.550309965202e-02
#   1 KSP Residual norm 4.971481536008e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.173799466966e-17
#   1 KSP Residual norm 3.072132136964e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.820000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.549757151199e-02
#   1 KSP Residual norm 5.182686323465e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.079512502139e-17
#   1 KSP Residual norm 4.077266902615e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.830000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.550064699038e-02
#   1 KSP Residual norm 5.296537177151e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.077723325679e-17
#   1 KSP Residual norm 3.229791881420e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.840000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.551333882758e-02
#   1 KSP Residual norm 5.133766212040e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.962182500559e-17
#   1 KSP Residual norm 2.671039649034e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.850000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.553463639559e-02
#   1 KSP Residual norm 5.395422661144e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.139098714311e-17
#   1 KSP Residual norm 1.605341113082e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.860000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.556252041138e-02
#   1 KSP Residual norm 5.114387712628e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.120469972952e-17
#   1 KSP Residual norm 8.410320673659e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.870000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.559509736140e-02
#   1 KSP Residual norm 5.436001930805e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.961413743012e-17
#   1 KSP Residual norm 1.843231510908e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.880000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.563110925097e-02
#   1 KSP Residual norm 5.240144470191e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.098097966165e-17
#   1 KSP Residual norm 6.126674903430e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.890000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566972891332e-02
#   1 KSP Residual norm 4.912569621931e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.085930812487e-17
#   1 KSP Residual norm 3.680604519364e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.900000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570986031151e-02
#   1 KSP Residual norm 5.076687031333e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.065769505884e-17
#   1 KSP Residual norm 1.593130925836e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.910000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574926971622e-02
#   1 KSP Residual norm 5.165182354598e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.967934773957e-17
#   1 KSP Residual norm 2.330017284671e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.920000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.578418243299e-02
#   1 KSP Residual norm 5.172016226292e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.901732256146e-17
#   1 KSP Residual norm 5.077305749282e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.930000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.581008985860e-02
#   1 KSP Residual norm 5.157175513378e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.948405551170e-17
#   1 KSP Residual norm 2.560405105420e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.940000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.582371537057e-02
#   1 KSP Residual norm 5.143284895620e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.048137518170e-17
#   1 KSP Residual norm 2.755179733155e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.950000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.582484337593e-02
#   1 KSP Residual norm 5.160650638420e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.866568476988e-17
#   1 KSP Residual norm 2.372767438088e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.960000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.581648140499e-02
#   1 KSP Residual norm 4.954286312279e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.096766380635e-17
#   1 KSP Residual norm 1.638335426758e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.970000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.580310186674e-02
#   1 KSP Residual norm 5.129310822633e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.807660814810e-17
#   1 KSP Residual norm 1.377089414349e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.980000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.578824971361e-02
#   1 KSP Residual norm 5.040438306536e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.144027211964e-17
#   1 KSP Residual norm 1.364287500786e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 5.990000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.577317856617e-02
#   1 KSP Residual norm 5.221485011351e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.284892504227e-17
#   1 KSP Residual norm 2.791164339966e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.000000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.575729615700e-02
#   1 KSP Residual norm 5.303207654006e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.135842915545e-17
#   1 KSP Residual norm 2.975500267848e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.010000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.573989995758e-02
#   1 KSP Residual norm 4.972189615510e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.242241574926e-17
#   1 KSP Residual norm 2.244320639542e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.020000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572176437900e-02
#   1 KSP Residual norm 5.162446001143e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.097875057233e-17
#   1 KSP Residual norm 2.108620803436e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.030000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570520441416e-02
#   1 KSP Residual norm 5.169371797394e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.218278031602e-17
#   1 KSP Residual norm 4.632585102190e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.040000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.569250266238e-02
#   1 KSP Residual norm 5.100586637355e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.101119028839e-17
#   1 KSP Residual norm 7.112375505196e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.050000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.568415902230e-02
#   1 KSP Residual norm 5.104174068950e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.958494109868e-17
#   1 KSP Residual norm 4.020647493430e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.060000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567867455260e-02
#   1 KSP Residual norm 5.018353509869e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.009530774840e-17
#   1 KSP Residual norm 1.971192028846e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.070000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567407083625e-02
#   1 KSP Residual norm 5.140134609089e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.232381021030e-17
#   1 KSP Residual norm 2.229177454664e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.080000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566966803102e-02
#   1 KSP Residual norm 5.273481302576e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.127554698776e-17
#   1 KSP Residual norm 4.898021704998e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.090000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566655414089e-02
#   1 KSP Residual norm 5.173626424825e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.155976104617e-17
#   1 KSP Residual norm 1.556197589698e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.100000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566654371930e-02
#   1 KSP Residual norm 5.034508800269e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.222748626839e-17
#   1 KSP Residual norm 3.155505169388e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.110000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567069930811e-02
#   1 KSP Residual norm 4.977047160682e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.012802985073e-17
#   1 KSP Residual norm 2.146779660266e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.120000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567860317275e-02
#   1 KSP Residual norm 5.124003515705e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.900292125517e-17
#   1 KSP Residual norm 2.327153500256e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.130000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.568875735726e-02
#   1 KSP Residual norm 5.003629083756e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.041196424627e-17
#   1 KSP Residual norm 2.559129703753e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.140000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.569961667238e-02
#   1 KSP Residual norm 4.927061722853e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.863557287214e-17
#   1 KSP Residual norm 2.623950803811e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.150000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.571040150214e-02
#   1 KSP Residual norm 5.163627645443e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.030755387058e-17
#   1 KSP Residual norm 2.032189849136e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.160000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572108922251e-02
#   1 KSP Residual norm 4.999475607770e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.978877658241e-17
#   1 KSP Residual norm 2.610596740668e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.170000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.573164220946e-02
#   1 KSP Residual norm 4.962227547117e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.036229816194e-17
#   1 KSP Residual norm 2.057002219441e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.180000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574117141560e-02
#   1 KSP Residual norm 5.278610002526e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.024545723052e-17
#   1 KSP Residual norm 2.663207989716e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.190000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574782907813e-02
#   1 KSP Residual norm 5.100798700079e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.183237304043e-17
#   1 KSP Residual norm 7.601895136418e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.200000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574960147535e-02
#   1 KSP Residual norm 4.947890922363e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.996578596802e-17
#   1 KSP Residual norm 1.035259225655e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.210000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574537081628e-02
#   1 KSP Residual norm 4.961968618908e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.198754727914e-17
#   1 KSP Residual norm 5.384440150573e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.220000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.573541517061e-02
#   1 KSP Residual norm 5.066376198362e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.134220537642e-17
#   1 KSP Residual norm 5.439582040245e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.230000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572105641875e-02
#   1 KSP Residual norm 5.035849732240e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.065761458933e-17
#   1 KSP Residual norm 8.020143908910e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.240000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570384062148e-02
#   1 KSP Residual norm 5.012099622430e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.323406421098e-17
#   1 KSP Residual norm 1.393382982555e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.250000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.568486501349e-02
#   1 KSP Residual norm 5.206441624221e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.268140834169e-17
#   1 KSP Residual norm 3.632491450009e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.260000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566464555765e-02
#   1 KSP Residual norm 5.125979169626e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.823292039678e-17
#   1 KSP Residual norm 1.817568708688e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.270000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.564356094494e-02
#   1 KSP Residual norm 5.036448003923e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.086026073199e-17
#   1 KSP Residual norm 3.467343429520e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.280000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.562259315415e-02
#   1 KSP Residual norm 4.941935603019e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.202308186841e-17
#   1 KSP Residual norm 2.925144288613e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.290000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560385779895e-02
#   1 KSP Residual norm 4.988946021878e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.057249394987e-17
#   1 KSP Residual norm 2.019607121779e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.300000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.559043830230e-02
#   1 KSP Residual norm 5.013786550918e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.072890958305e-17
#   1 KSP Residual norm 8.420006216412e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.310000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.558546112235e-02
#   1 KSP Residual norm 5.363298801113e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.977468119409e-17
#   1 KSP Residual norm 1.234761039718e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.320000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.559092967879e-02
#   1 KSP Residual norm 5.170549580135e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.993490822101e-17
#   1 KSP Residual norm 6.320657753470e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.330000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560703497075e-02
#   1 KSP Residual norm 5.033408462550e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.076260429014e-17
#   1 KSP Residual norm 3.211763236611e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.340000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.563230533409e-02
#   1 KSP Residual norm 5.099119916486e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.792718050311e-17
#   1 KSP Residual norm 1.607502154804e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.350000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.566441018342e-02
#   1 KSP Residual norm 5.044792925119e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.287733172546e-17
#   1 KSP Residual norm 4.336242566889e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.360000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570104634130e-02
#   1 KSP Residual norm 5.241592952596e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.878211793969e-17
#   1 KSP Residual norm 1.433727192134e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.370000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574023412937e-02
#   1 KSP Residual norm 5.151372399500e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.951051564945e-17
#   1 KSP Residual norm 3.638042715364e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.380000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.577974555557e-02
#   1 KSP Residual norm 5.021985338294e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.222878177599e-17
#   1 KSP Residual norm 1.423309692766e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.390000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.581629511340e-02
#   1 KSP Residual norm 5.076128800573e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.134866774234e-17
#   1 KSP Residual norm 4.206069807350e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.400000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.584567724949e-02
#   1 KSP Residual norm 5.024538337035e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.242188018353e-17
#   1 KSP Residual norm 1.335788116678e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.410000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.586422476537e-02
#   1 KSP Residual norm 5.179949483287e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.209052425739e-17
#   1 KSP Residual norm 4.339355017703e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.420000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.587042370942e-02
#   1 KSP Residual norm 5.009264317621e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.310848705688e-17
#   1 KSP Residual norm 5.030990432284e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.430000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.586521038970e-02
#   1 KSP Residual norm 5.246112784079e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.054076722913e-17
#   1 KSP Residual norm 2.469516922998e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 6.440000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.585093218195e-02
#   1 KSP Residual norm 5.136068025907e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.205853989452e-17
#   1 KSP Residual norm 1.078388356502e-30
# ...
# -------------------------------
# |> Solving at time= 9.530000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574619804433e-02
#   1 KSP Residual norm 5.138556559755e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.352932946592e-17
#   1 KSP Residual norm 1.896393039704e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.540000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.573046808710e-02
#   1 KSP Residual norm 5.176250727903e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.462767985656e-17
#   1 KSP Residual norm 3.034700093323e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.550000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572269833910e-02
#   1 KSP Residual norm 5.104267335806e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.686683399723e-17
#   1 KSP Residual norm 4.012301795783e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.560000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572299540053e-02
#   1 KSP Residual norm 5.030901360839e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.184366016986e-17
#   1 KSP Residual norm 3.200542432079e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.570000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572931260798e-02
#   1 KSP Residual norm 4.932399007762e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.270626821969e-17
#   1 KSP Residual norm 4.138243518673e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.580000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.573888474674e-02
#   1 KSP Residual norm 5.046294325976e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.089014351625e-17
#   1 KSP Residual norm 1.177632964709e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.590000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574965267414e-02
#   1 KSP Residual norm 5.256373750156e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.279896722981e-17
#   1 KSP Residual norm 1.145131928612e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.600000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.576039466849e-02
#   1 KSP Residual norm 5.224289812615e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.095299013757e-17
#   1 KSP Residual norm 3.082858713949e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.610000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.576986499705e-02
#   1 KSP Residual norm 5.148865045709e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.326324488190e-17
#   1 KSP Residual norm 1.437539174175e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.620000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.577629879414e-02
#   1 KSP Residual norm 5.154465474507e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.467746487192e-17
#   1 KSP Residual norm 3.265480589737e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.630000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.577803167612e-02
#   1 KSP Residual norm 5.245249437869e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.224738406380e-17
#   1 KSP Residual norm 5.081833777509e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.640000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.577453623281e-02
#   1 KSP Residual norm 5.283541500550e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.450922347720e-17
#   1 KSP Residual norm 2.653456354720e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.650000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.576662317264e-02
#   1 KSP Residual norm 5.034222311959e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.428456686004e-17
#   1 KSP Residual norm 9.630232153935e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.660000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.575546684363e-02
#   1 KSP Residual norm 5.001566392288e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.215657555295e-17
#   1 KSP Residual norm 1.705264447231e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.670000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574139892055e-02
#   1 KSP Residual norm 5.074746429306e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.423149095616e-17
#   1 KSP Residual norm 2.290832101274e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.680000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.572370581623e-02
#   1 KSP Residual norm 5.129866610755e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.129784543185e-17
#   1 KSP Residual norm 1.409501823177e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.690000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.570174182885e-02
#   1 KSP Residual norm 5.145625903513e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.190892491451e-17
#   1 KSP Residual norm 9.574730408874e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.700000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567644003367e-02
#   1 KSP Residual norm 5.047540858533e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.968330435658e-17
#   1 KSP Residual norm 1.268265094479e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.710000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.565083575701e-02
#   1 KSP Residual norm 5.060745742345e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.566726481856e-17
#   1 KSP Residual norm 1.415645433470e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.720000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.562893023003e-02
#   1 KSP Residual norm 5.100776265902e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.188175554309e-17
#   1 KSP Residual norm 2.622448897240e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.730000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.561361674092e-02
#   1 KSP Residual norm 5.384303904974e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.378881713867e-17
#   1 KSP Residual norm 1.236121191464e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.740000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560529853345e-02
#   1 KSP Residual norm 5.148639824153e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.088743178688e-17
#   1 KSP Residual norm 4.305852150913e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.750000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560228959087e-02
#   1 KSP Residual norm 5.339318454294e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.514639633634e-17
#   1 KSP Residual norm 2.008597882643e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.760000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560246945712e-02
#   1 KSP Residual norm 5.218752786289e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.219985378738e-17
#   1 KSP Residual norm 2.137679524590e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.770000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560458188199e-02
#   1 KSP Residual norm 5.322819423121e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.392030297468e-17
#   1 KSP Residual norm 3.024747021456e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.780000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.560818443072e-02
#   1 KSP Residual norm 4.975194520002e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.331914151945e-17
#   1 KSP Residual norm 7.762417675067e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.790000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.561282637041e-02
#   1 KSP Residual norm 5.002254652390e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.967970305872e-17
#   1 KSP Residual norm 1.068783692656e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.800000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.561775213554e-02
#   1 KSP Residual norm 5.277860010936e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 7.977402022284e-17
#   1 KSP Residual norm 1.022289738030e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.810000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.562261006701e-02
#   1 KSP Residual norm 5.229044889265e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.299692779796e-17
#   1 KSP Residual norm 1.749346457863e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.820000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.562840297151e-02
#   1 KSP Residual norm 5.199874890536e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.269804050218e-17
#   1 KSP Residual norm 1.841534813751e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.830000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.563762162433e-02
#   1 KSP Residual norm 5.116589671118e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.366401728125e-17
#   1 KSP Residual norm 1.639402717834e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.840000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.565326680789e-02
#   1 KSP Residual norm 5.069836478740e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.101545866335e-17
#   1 KSP Residual norm 2.224793589328e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.850000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.567739879061e-02
#   1 KSP Residual norm 5.258186344941e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.200884317045e-17
#   1 KSP Residual norm 4.043850729153e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.860000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.571017429156e-02
#   1 KSP Residual norm 5.424918749664e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.402312311655e-17
#   1 KSP Residual norm 3.586664769099e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.870000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.574988606480e-02
#   1 KSP Residual norm 5.144985367653e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.244049454181e-17
#   1 KSP Residual norm 1.952337621107e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.880000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.579373897948e-02
#   1 KSP Residual norm 5.339852234271e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.347850175363e-17
#   1 KSP Residual norm 2.346192283232e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.890000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.583871131015e-02
#   1 KSP Residual norm 5.107316708656e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.393098281822e-17
#   1 KSP Residual norm 1.537332594963e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.900000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.588216450133e-02
#   1 KSP Residual norm 5.308657817428e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.314031940403e-17
#   1 KSP Residual norm 1.371292090940e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.910000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.592224598783e-02
#   1 KSP Residual norm 5.231186804311e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.341998965946e-17
#   1 KSP Residual norm 1.405297131676e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.920000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.595793137920e-02
#   1 KSP Residual norm 5.068910033556e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.450001084025e-17
#   1 KSP Residual norm 3.393040742883e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.930000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.598835584217e-02
#   1 KSP Residual norm 5.089580385269e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.248046354894e-17
#   1 KSP Residual norm 2.369855005347e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.940000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.601179766739e-02
#   1 KSP Residual norm 5.029965339895e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.046340783553e-17
#   1 KSP Residual norm 1.769766144924e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.950000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.602557013031e-02
#   1 KSP Residual norm 5.124598987310e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.207469355713e-17
#   1 KSP Residual norm 3.873267938369e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.960000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.602747973374e-02
#   1 KSP Residual norm 5.268528730918e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.478796091283e-17
#   1 KSP Residual norm 1.430798683882e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.970000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.601766519549e-02
#   1 KSP Residual norm 5.262633759082e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.496175289252e-17
#   1 KSP Residual norm 8.246522148905e-31
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.980000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.599889709749e-02
#   1 KSP Residual norm 5.363788348278e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.264137556254e-17
#   1 KSP Residual norm 1.953449177475e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 9.990000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.597492406458e-02
#   1 KSP Residual norm 5.139373929909e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.269669036045e-17
#   1 KSP Residual norm 3.931803246516e-30
# Number of interations= 2
# -------------------------------
# |> Solving at time= 10.000000
#
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 2.594839648120e-02
#   1 KSP Residual norm 5.228792080453e-18
#   Residual norms for nls_solve_ solve.
#   0 KSP Residual norm 8.286267925544e-17
#   1 KSP Residual norm 4.354153243198e-31
# Number of interations= 2

# %% [markdown]
# # Homework 4

# %% [markdown]
# 1. **Computing forces on the object**
#
# Consider the computation of the forces over the obtacle that are given by
#
# $$
# \mathbf{F} = \int_{\Gamma_{obs}}{\boldsymbol{\sigma}(\mathbf{u},p) \cdot \check{\mathbf{n}}}\,ds =
# $$
#
# where
#
# $$
# \boldsymbol{\sigma}(\mathbf{u},p) = -p\mathbf{I} + 2\,\mu\, \boldsymbol{\varepsilon}(\mathbf{u})
# $$
#
# The task for this homerwork is:
#
# * Check the implementation in the cell below and make sure to understand the details.
#
# * Take `T = 10` and `num_steps = 1500`, $\gamma = 0$, $\theta = 0.5$. Run the code for three different mesh refinements to compare the results of $\mathbf{F}$ as a function of time. In order to change the mesh refinement got the cell where the mesh is created and set the variable `res_min` to an appropriate
# value, e.g. `r/4`, `r/8` and `r/16`. The latter case may take some time to
# run in the colab environment.

# %%
n = -FacetNormal(msh) # Normal pointing out of obstacle
ds_obs = Measure("ds", domain=msh, subdomain_data=boundaries, subdomain_id=obstacle_marker)

def sigma(u,p):
  return 2*mu*epsilon(u) - p*Identity(2)

# Loop over time steps
t = 0
teval = np.linspace(0,T, num_steps, dtype=np.float64)
forcex = np.zeros(num_steps, dtype=np.float64)
forcey = np.zeros(num_steps, dtype=np.float64)
for i in range(num_steps):
    
    t += dt

    print("-------------------------------")
    print(f"|> Solving at time= {t:f}\n")
    log.set_log_level(log.LogLevel.INFO)
    niters, converged = solver.solve(w)
    assert(converged)
    print(f"Number of interations= {niters:d}")

    # Update the previous solution with the last computed value
    w_n.x.array[:] = w.x.array[:]
    w_n.x.scatter_forward()

    upl = w_n.sub(0).collapse()
    ppl = w_n.sub(1).collapse()
    
    forcexform = fem.form( dot(sigma(upl,ppl), n)[0] * ds_obs )
    forceyform = fem.form( dot(sigma(upl,ppl), n)[1] * ds_obs )
    forcex[i] = msh.comm.allreduce(fem.assemble_scalar(forcexform), op=MPI.SUM)
    forcey[i] = msh.comm.allreduce(fem.assemble_scalar(forceyform), op=MPI.SUM)

# End loop over time steps

# %%
plt.figure(figsize= (9,6))
plt.rcParams['font.size'] = '16'
plt.axes(facecolor = "lightgray")
plt.xlabel('time',fontsize=20)
plt.ylabel('Force', fontsize=20)
l = plt.plot(teval[10:], forcex[10:], '-r', teval[10:], forcey[10:], '-b')
plt.setp(l, 'markersize', 6)
plt.setp(l, 'markerfacecolor', 'white')
plt.legend(['$F_x(t) = \int_{\Gamma_{obs}}\mathcal{F}_x\,ds$'])
plt.grid()
plt.show()

# %% [markdown]
# 2. **OPTIONAL: Stabilization of convective terms**
#
# The treatment of the convective term
#
# $$
# (\nabla\mathbf{u})\cdot \mathbf{u}= (\mathbf{u} \cdot \nabla)(\mathbf{u})
# $$
#
# is also a delicate issue. A robust implementation would include some sort of stabilization, tipically, the **SUPG** (Streamline Upwind Petrov Galerkin) method, which amounts to add the following term to the variational formulation
#
# \begin{equation}
# \mbox{SUPG} = \sum_{K \in \mathcal{T}_h}{\tau_K \,\int_{K}{\mathscr{P}(\mathbf{v}_h) \cdot \mathscr{R}(\mathbf{u}_h)}}\,dx \nonumber
# \end{equation}
#
# where
# $\mathscr{R}(\mathbf{u}) = \rho\left (\dfrac{\partial{\mathbf{u}}}{\partial{t}} +  \mathbf{u} \cdot \nabla \mathbf{u}\right )
# - \nabla \cdot ( 2 \, \mu \boldsymbol{\varepsilon}(\mathbf{u})) + \nabla{p} - \mathbf{f}$,$~$ is the residual of the momentum equation
# and the elementwise stabilization parameter $\tau_K$ is taken as
#
# \begin{equation}
# \tau_K = \left [ c_1\frac{\mu}{\rho \, h_K^2} + c_2\frac{\|\mathbf{u}\|_{\infty,K}}{h_K} \right ]^{-1} \nonumber
# \end{equation}
#
# and the perturbed test function $\mathscr{P}(\mathbf{v})$ is
#
# \begin{equation}
# \mathscr{P}(\mathbf{v}) = (\mathbf{u} \cdot \nabla) \mathbf{v}  \nonumber
# \end{equation}
#
# For our current implementation and for the problems to be solved we will assume the convective term is controlled by limiting the Reynolds number Re$=\dfrac{\rho \, U_{\max} H}{\mu}$ to relatively low values.
#
# *Implementation of such stabilization method is left as an optional exercise for the advanced students*.
